# %% [markdown]
# # Limpieza de datos
# Para la limpieza de datos lo que haremos sera limpiar por cada uno de los archivos y por ultimo unirlos en un CSV

# %%
import pandas as pd
import os

# %%
files = [file for file in os.listdir("./csv_files") if file.endswith('.csv') and file != 'all_institutes.csv']

print("Files to use:")
for file in files:
    print(file)
# Out:
# Files to use:
# alta_verapaz.csv
# baja_verapaz.csv
# chimaltenango.csv
# chiquimula.csv
# ciudad_capital.csv
# el_progreso.csv
# escuintla.csv
# guatemala.csv
# huehuetenango.csv
# izabal.csv
# jalapa.csv
# jutiapa.csv
# peten.csv
# quetzaltenango.csv
# quiche.csv
# retalhuleu.csv
# sacatepequez.csv
# santa_rosa.csv
# san_marcos.csv
# solola.csv
# suchitepequez.csv
# totonicapan.csv
# zacapa.csv

# %%
# if folder cleanCSV does not exist, create it
if not os.path.exists('cleanCSV'):
    os.makedirs('cleanCSV')

# %%
drops = ["CODIGO"]
fillWithdesconocido = ["DISTRITO","DEPARTAMENTO","MUNICIPIO","ESTABLECIMIENTO",
                       "DIRECCION","SUPERVISOR","DIRECTOR","NIVEL","SECTOR",
                       "AREA","STATUS","MODALIDAD","JORNADA","PLAN","DEPARTAMENTAL"]

specialReplace = {
    "TELEFONO":0
}


def cleanFile(file):

    name = file.split("/")[-1]
    print("Cleaning file: " +name)
    
    
    
    
    
    for column in drops:
        
        df = pd.read_csv(file, sep=',')
        print(f"\n\nCleaning column {column}")
        print(f"We will remove all the rows that have a missing value in the {column} column")
        # check if there are any missing values in the CODIGO column
        print(f"Number of missing values in CODIGO {column}: " + str(df[column].isnull().sum()))
        df = df.dropna(subset=[column])
    
    for column in fillWithdesconocido:
        print(f"\n\nCleaning column {column}")
        print(f"We will remove all the rows that have a missing value in the {column} column")
        # check if there are any missing values in the DISTRITO column
        print(f"Number of missing values in {column} column: " + str(df[column].isnull().sum()))
        # change the missing values to "desconocido"
        df[column] = df[column].fillna("desconocido")
        
    
    for column in specialReplace.keys():
        print(f"\n\nCleaning column {column}")
        print(f"We will remove all the rows that have a missing value in the {column} column")
        # check if there are any missing values in the TELEFONO column
        print(f"Number of missing values in {column} column: " + str(df[column].isnull().sum()))
        # change the missing values to "desconocido"
        df[column] = df[column].fillna(specialReplace[column])
    
    # convert all to lowercase
    df = df.apply(lambda x: x.astype(str).str.lower())
    
    # remove accents
    df = df.apply(lambda x: x.astype(str).str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
    
    # remove leading and trailing spaces
    df = df.apply(lambda x: x.astype(str).str.strip())
    
    # remove multiple spaces
    df = df.apply(lambda x: x.astype(str).str.replace(' +', ' '))
    
    # remove the last row
    df = df.iloc[:-1]
    
    # if the TELEFONO column has a value more of one phone number separated by - rjust keep one
    df["TELEFONO"] = df["TELEFONO"].apply(lambda x: x.split("-")[0])
    
    df["TELEFONO"] = df["TELEFONO"].apply(lambda x: x.split("/")[0])
    
    df["TELEFONO"] = df["TELEFONO"].apply(lambda x: x.split(" ")[0])
    
    df["TELEFONO"] = df["TELEFONO"].apply(lambda x: x.split(",")[0])
    
    # remove the dot from the TELEFONO column
    df["TELEFONO"] = df["TELEFONO"].apply(lambda x: x.split(".")[0])
    
    # convert the TELEFONO column to int
    df["TELEFONO"] = df["TELEFONO"].astype(int)
    
    # convert the TELEFONO column to string
    df["TELEFONO"] = df["TELEFONO"].astype(str)
    
    
    # replace the 0 with desconocido
    df["TELEFONO"] = df["TELEFONO"].replace("0","desconocido")
    
    
    
    
    
    
    # save the cleaned file
    df.to_csv("./cleanCSV/cleaned_"+name, index=False)

# %%
subPath = "./csv_files/"
for file in files:
    cleanFile(subPath+file)
# Out:
# Cleaning file: alta_verapaz.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 3
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 3
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 3
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 75
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 21
# Cleaning file: baja_verapaz.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 2
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 1
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 2
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 12
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 7
# Cleaning file: chimaltenango.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 3
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 1
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 3
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 46
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 15
# Cleaning file: chiquimula.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 2
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 3
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 2
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 39
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 20
# Cleaning file: ciudad_capital.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 68
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 6
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 68
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 523
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 103
# Cleaning file: el_progreso.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 4
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 1
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 4
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 31
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 14
# Cleaning file: escuintla.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 12
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 3
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 12
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 73
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 38
# Cleaning file: guatemala.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 55
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 4
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 55
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 289
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 83
# Cleaning file: huehuetenango.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 6
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 5
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 6
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 58
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 28
# Cleaning file: izabal.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 3
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 1
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 3
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 7
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 14
# Cleaning file: jalapa.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 1
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 3
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 1
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 11
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 7
# Cleaning file: jutiapa.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 7
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 7
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 7
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 42
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 20
# Cleaning file: peten.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 12
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 9
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 12
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 58
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 32
# Cleaning file: quetzaltenango.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 19
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 3
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 19
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 88
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 29
# Cleaning file: quiche.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 2
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 1
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 2
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 21
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 11
# Cleaning file: retalhuleu.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 3
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 1
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 3
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 24
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 16
# Cleaning file: sacatepequez.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 3
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 1
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 4
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 62
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 13
# Cleaning file: santa_rosa.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 2
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 3
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 2
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 20
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 9
# Cleaning file: san_marcos.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 11
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 7
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 11
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 83
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 37
# Cleaning file: solola.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 2
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 4
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 2
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 24
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 9
# Cleaning file: suchitepequez.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 7
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 4
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 7
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 52
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 29
# Cleaning file: totonicapan.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 2
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 2
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 2
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 8
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 7
# Cleaning file: zacapa.csv
#
#
# Cleaning column CODIGO
# We will remove all the rows that have a missing value in the CODIGO column
# Number of missing values in CODIGO CODIGO: 1
#
#
# Cleaning column DISTRITO
# We will remove all the rows that have a missing value in the DISTRITO column
# Number of missing values in DISTRITO column: 3
#
#
# Cleaning column DEPARTAMENTO
# We will remove all the rows that have a missing value in the DEPARTAMENTO column
# Number of missing values in DEPARTAMENTO column: 1
#
#
# Cleaning column MUNICIPIO
# We will remove all the rows that have a missing value in the MUNICIPIO column
# Number of missing values in MUNICIPIO column: 1
#
#
# Cleaning column ESTABLECIMIENTO
# We will remove all the rows that have a missing value in the ESTABLECIMIENTO column
# Number of missing values in ESTABLECIMIENTO column: 1
#
#
# Cleaning column DIRECCION
# We will remove all the rows that have a missing value in the DIRECCION column
# Number of missing values in DIRECCION column: 2
#
#
# Cleaning column SUPERVISOR
# We will remove all the rows that have a missing value in the SUPERVISOR column
# Number of missing values in SUPERVISOR column: 3
#
#
# Cleaning column DIRECTOR
# We will remove all the rows that have a missing value in the DIRECTOR column
# Number of missing values in DIRECTOR column: 5
#
#
# Cleaning column NIVEL
# We will remove all the rows that have a missing value in the NIVEL column
# Number of missing values in NIVEL column: 1
#
#
# Cleaning column SECTOR
# We will remove all the rows that have a missing value in the SECTOR column
# Number of missing values in SECTOR column: 1
#
#
# Cleaning column AREA
# We will remove all the rows that have a missing value in the AREA column
# Number of missing values in AREA column: 1
#
#
# Cleaning column STATUS
# We will remove all the rows that have a missing value in the STATUS column
# Number of missing values in STATUS column: 1
#
#
# Cleaning column MODALIDAD
# We will remove all the rows that have a missing value in the MODALIDAD column
# Number of missing values in MODALIDAD column: 1
#
#
# Cleaning column JORNADA
# We will remove all the rows that have a missing value in the JORNADA column
# Number of missing values in JORNADA column: 1
#
#
# Cleaning column PLAN
# We will remove all the rows that have a missing value in the PLAN column
# Number of missing values in PLAN column: 1
#
#
# Cleaning column DEPARTAMENTAL
# We will remove all the rows that have a missing value in the DEPARTAMENTAL column
# Number of missing values in DEPARTAMENTAL column: 1
#
#
# Cleaning column TELEFONO
# We will remove all the rows that have a missing value in the TELEFONO column
# Number of missing values in TELEFONO column: 8
